# %% [markdown]
# # 🧑‍🍳 Neosantara AI Cookbook: Multimodal OCR
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/neosantara-xyz/examples/blob/main/cookbook/advanced/multimodal-ocr.ipynb)
#
# This notebook demonstrates how to extract structured data from images using vision-capable models via Neosantara AI Gateway.
#
# ### 📖 Documentation
# - [OCR Extraction API Reference](https://docs.neosantara.xyz/api-reference/vision/ocr-extraction)
# - [Structured Output Guide](https://docs.neosantara.xyz/en/capability/structured)

# %%
# !pip install openai

try:
    from google.colab import userdata
    import os
    os.environ["NEOSANTARA_API_KEY"] = userdata.get('NEOSANTARA_API_KEY')
except ImportError:
    import os

# %%
from openai import OpenAI
import os

client = OpenAI(
    api_key=os.getenv("NEOSANTARA_API_KEY"),
    base_url="https://api.neosantara.xyz/v1"
)

# %%
response = client.chat.completions.create(
    model="glm-4.6",
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "Extract merchant name, date, and total from this receipt in JSON format."},
                {
                    "type": "image_url",
                    "image_url": {"url": "https://docs.neosantara.xyz/assets/receipt-example.jpg"}
                }
            ]
        }
    ],
    response_format={"type": "json_object"}
)

print(response.choices[0].message.content)
