# %% [markdown]
# # 🧑‍🍳 Neosantara AI Cookbook: Streaming Chat
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/neosantara-xyz/examples/blob/main/cookbook/beginner/streaming-chat.ipynb)
#
# This notebook demonstrates how to stream chat completions in real-time using Neosantara AI.
#
# ### 📖 Documentation
# - [Streaming Capability Guide](https://docs.neosantara.xyz/en/capability/stream)
# - [Chat Completions Reference](https://docs.neosantara.xyz/en/sdk/openai-compat/chat-completions)

# %%
# !pip install openai

try:
    from google.colab import userdata
    import os
    os.environ["NEOSANTARA_API_KEY"] = userdata.get('NEOSANTARA_API_KEY')
except ImportError:
    import os

# %%
from openai import OpenAI
import os

client = OpenAI(
    api_key=os.getenv("NEOSANTARA_API_KEY"),
    base_url="https://api.neosantara.xyz/v1"
)

# %%
stream = client.chat.completions.create(
    model="nusantara-base",
    messages=[
        {"role": "user", "content": "Write a short poem about Jakarta."}
    ],
    stream=True
)

for chunk in stream:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="", flush=True)
